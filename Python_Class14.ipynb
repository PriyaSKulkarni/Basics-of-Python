# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '2.0.3'

# %%
s1 = pd.Series()
type(s1)
# Out:
# pandas.core.series.Series

# %%
s1 = pd.Series([10,20,30,40,50])
s1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s1.values
# Out:
# array([10, 20, 30, 40, 50])

# %%
s1 = pd.Series([10,20,30,40,50], index=[100,200,300,400,500])
s1
# Out:
# 100    10
# 200    20
# 300    30
# 400    40
# 500    50
# dtype: int64

# %%
s1 = pd.Series([10,20,30,40,50], index=['a','b','c','d','e'])
s1
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
df = pd.DataFrame({"Score":s1})
df
# Out:
#    Score
# a     10
# b     20
# c     30
# d     40
# e     50

# %%
age = {'Bob':25, 'Alex': 45,'Sara':35}
s2 = pd.Series(age)

# %%
s2
# Out:
# Bob     25
# Alex    45
# Sara    35
# dtype: int64

# %%
df = pd.DataFrame({'Age':s2})
df
# Out:
#       Age
# Bob    25
# Alex   45
# Sara   35

# %%
df.index
# Out:
# Index(['Bob', 'Alex', 'Sara'], dtype='object')

# %%
df.columns
# Out:
# Index(['Age'], dtype='object')

# %%
student = [['Alex','Marketing',3.63],['Sarah','Finance',3.85],['Martin','Accounting',3.55]]
df = pd.DataFrame(student, columns = ['Name','Major','CGPA'], index = [1001,1002,1003])

# %%
df
# Out:
#         Name       Major  CGPA
# 1001    Alex   Marketing  3.63
# 1002   Sarah     Finance  3.85
# 1003  Martin  Accounting  3.55

# %%
employee = { 'Name':['Alex','Bob','John'],
            'Salary': [10000,20000,300] ,
  'Position':['Executive','CEO','Manager']}

# %%
df = pd.DataFrame(employee)

# %%
df.head(1)
# Out:
#    Name  Salary   Position
# 0  Alex   10000  Executive

# %%
df.tail(1)
# Out:
#    Name  Salary Position
# 2  John     300  Manager

# %%
df.sample(1)
# Out:
#    Name  Salary Position
# 2  John     300  Manager

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      3 non-null      object
#  1   Salary    3 non-null      int64
#  2   Position  3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 200.0+ bytes

# %%
df.describe() # consider only numbers field
# Out:
#              Salary
# count      3.000000
# mean   10100.000000
# std     9850.380703
# min      300.000000
# 25%     5150.000000
# 50%    10000.000000
# 75%    15000.000000
# max    20000.000000

# %%
df.isnull()
# Out:
#     Name  Salary  Position
# 0  False   False     False
# 1  False   False     False
# 2  False   False     False

# %% [markdown]
# Read Data

# %%
path ="/content/drive/MyDrive/Pythonclass/Dataset/data_02.csv"
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv(path, header = None, names = ['FName','Lname','Course','Score'])
df.head()
# Out:
#        FName      Lname    Course  Score
# 0      Alex       Smith   Python      92
# 1     James       Jones      C++      97
# 2      Mary    Williams   Python      98
# 3  Patricia       Brown     Java      87
# 4  Jennifer      Taylor     HTML      88

# %%
df.shape
# Out:
# (16, 4)

# %%
path = "/content/drive/MyDrive/Pythonclass/Dataset/data_04.csv"

# %%
df = pd.read_csv(path, comment ="#", sep ='\t')
df
# Out:
#       first name  last name  experience   score
# 0          Alex       Smith     Python       92
# 1         James       Jones        C++       97
# 2          Mary    Williams     Python       98
# 3      Patricia       Brown       Java       87
# 4      Jennifer      Taylor       HTML       88
# 5         Emily      Davies   Android        90
# 6       Michael      Wilson     Python       91
# 7       Jessica       Evans        C++       95
# 8          John      Thomas     Python       90
# 9        Thomas     Roberts       Java       89
# 10  Christopher      Martin     Python       83
# 11      Barbara         Lee        C++       86
# 12      Matthew    Anderson          R       97
# 13         Mark       White     Python       91
# 14        Nancy      Taylor       Java       96
# 15       Andrew       Smith          R       92

# %%
df = pd.read_csv(path, skiprows= 3, sep ='\t')
df
# Out:
#       first name  last name  experience   score
# 0          Alex       Smith     Python       92
# 1         James       Jones        C++       97
# 2          Mary    Williams     Python       98
# 3      Patricia       Brown       Java       87
# 4      Jennifer      Taylor       HTML       88
# 5         Emily      Davies   Android        90
# 6       Michael      Wilson     Python       91
# 7       Jessica       Evans        C++       95
# 8          John      Thomas     Python       90
# 9        Thomas     Roberts       Java       89
# 10  Christopher      Martin     Python       83
# 11      Barbara         Lee        C++       86
# 12      Matthew    Anderson          R       97
# 13         Mark       White     Python       91
# 14        Nancy      Taylor       Java       96
# 15       Andrew       Smith          R       92

# %%
path = "/content/drive/MyDrive/Pythonclass/Dataset/titanic.csv"
df= pd.read_csv(path)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
age = df['Age']
age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
type(age)
# Out:
# pandas.core.series.Series

# %%
age.mean()
# Out:
# 29.69911764705882

# %%
age.max()
# Out:
# 80.0

# %%
age.min()
# Out:
# 0.42

# %%
df.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#loc -> Location, need to give name of the column
#iloc - integer location, need to give integer value

# %%
df.iloc[:,:]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.iloc[0,1]
# Out:
# 0

# %%
df.iloc[0,[1,5]]
# Out:
# Survived       0
# Age         22.0
# Name: 0, dtype: object

# %%
df.iloc[:5,:3]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3

# %%
df.iloc[[0,-1],-3:]
# Out:
#      Fare Cabin Embarked
# 0    7.25   NaN        S
# 890  7.75   NaN        Q
